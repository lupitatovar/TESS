# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import *
import astropy
from astropy import constants as ac
from astroquery.mast import Observations
import lightkurve
import celerite
from celerite import terms
from scipy.optimize import minimize
from astropy.io import fits
from astropy.table import Table

# %% [markdown]
# ### Loading in TESS Sector 14 Data

# %%
from lightkurve import search_lightcurvefile
from lightkurve import search_targetpixelfile
target = '273589987'
gj1243_tess = search_lightcurvefile(target,cadence='short').download_all()

# %%
gj1243_tess
# Out:
# LightCurveFileCollection of 13 objects:
# 	KIC 9726699 (11 KeplerLightCurveFiles) Quarters: 6,6,10,10,10,12,12,12,13,13,13
# 	TIC 273589987 (2 KeplerLightCurveFiles) None: 0,1

# %%
gj1243_tess[11].scatter()

# %% [markdown]
# ### Loading in Flares table

# %%
fbeye = pd.read_csv('gj1243_tess_flares.dat.fbeye',delim_whitespace=True,comment='#',names = ['Event_ID', 'Start_INDX', 'Stop_INDX', 't_peak', 't_start', 't_stop', 't_rise', 't_decay', 
            'Flux_peak', 'Equiv_Dur', 'S/N', 'CPLX_flg', 'MLTPK_flg', 'MLTPK_num', 't_MLTPK', 'L_mltpk', 
            'MLTPK_INDX', 'quies','x'])[1:]

# %%
#mask the flares we found
t_starts = fbeye.loc[:,'t_start'].values
t_stops = fbeye.loc[:,'t_stop'].values
flux_peak = fbeye.loc[:,'Flux_peak'].values

#mask array for TESS lightcurve
f_mask = np.zeros_like(gj1243_tess[11].time, dtype=bool)

# %%
for i in range(len(t_starts)):
    temp = (gj1243_tess[11].time >= t_starts[i]) & (gj1243_tess[11].time <= t_stops[i])
    f_mask = f_mask + temp 
print(f_mask)


no_flare = np.where((f_mask == False))[0]
flares = np.where((f_mask == True))[0]
# Out:
# [False False False ... False False False]

# %%
gj1243_tess[11].time[:9350]
# Out:
# array([1683.35617589, 1683.3575648 , 1683.35895371, ..., 1697.39939546,
#        1697.40078436, 1697.40217326])

# %%
flares_x=gj1243_tess[11].time[f_mask]
#flares_x[:9200]
flares_y = gj1243_tess[11].PDCSAP_FLUX.flux[f_mask]/np.nanmedian(gj1243_tess[11].PDCSAP_FLUX.flux)
print(len(flares_y[:9350]))
print(len(gj1243_tess[11].PDCSAP_FLUX.flux[f_mask]/np.nanmedian(gj1243_tess[11].PDCSAP_FLUX.flux[f_mask])))
# Out:
# 831
# 831

# %%
print(np.nanmedian(gj1243_tess[11].PDCSAP_FLUX.flux[f_mask]))
print(np.nanmedian(gj1243_tess[11].PDCSAP_FLUX.flux[9350:]))
print(np.nanmedian(gj1243_tess[11].PDCSAP_FLUX.flux[:9200]))
print(np.nanmedian(gj1243_tess[11].PDCSAP_FLUX.flux))
# Out:
# 11396.067
# 11352.604
# 11354.549
# 11353.514

# %% [markdown]
# ### Plotting the TESS lightcurve with identified flares

# %%
fig,ax = plt.subplots(figsize=(16,8))
font = {'size'   : 20}
plt.rc('font', **font)

#plotting the TESS light curve (exculdes missing data)
plt.plot(gj1243_tess[11].time[:9200],gj1243_tess[11].PDCSAP_FLUX.flux[:9200]/np.nanmedian(gj1243_tess[11].PDCSAP_FLUX.flux),
         linewidth=0.5,alpha=0.95)
plt.plot(gj1243_tess[11].time[9350:],gj1243_tess[11].PDCSAP_FLUX.flux[9350:]/np.nanmedian(gj1243_tess[11].PDCSAP_FLUX.flux),
         linewidth=0.5,color='C0',alpha=0.95)

plt.scatter(flares_x,flares_y,linewidth=0.5,color='orange',s=25)

ax.set_ylim([0.99,1.08])
ax.set_xlim([1683.3,1710])

#over plotting the flares that we identified


#axes
#axes
plt.rcParams['axes.linewidth']=1.1

plt.tick_params(axis='both',direction="in")
from matplotlib.ticker import (AutoMinorLocator,MultipleLocator)
ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.tick_params(which='minor', direction='in',width=1.2,length=4)
ax.yaxis.set_minor_locator(MultipleLocator(.01))

plt.tick_params(axis='both',direction="in",width=1.5,length=8)


plt.xlabel('Time - 2457000 [BTJD days]')
plt.ylabel('Normalized Flux')
plt.tick_params(axis='both',direction="inout")


plt.savefig('gj1243_tess_lc.pdf',dpi=300, bbox_inches='tight', pad_inches=0.5)

# %%
fig,ax = plt.subplots(figsize=(18,8))
font = {'size'   : 24}
plt.rc('font', **font)

#plotting the TESS light curve (exculdes missing data)
plt.plot(gj1243_tess[11].time[:9200],gj1243_tess[11].PDCSAP_FLUX.flux[:9200],
         linewidth=0.5,alpha=0.95)
plt.plot(gj1243_tess[11].time[9350:],gj1243_tess[11].PDCSAP_FLUX.flux[9350:],
         linewidth=0.5,color='C0',alpha=0.95)

plt.scatter(gj1243_tess[11].time[f_mask],gj1243_tess[11].PDCSAP_FLUX.flux[f_mask],
            linewidth=0.5,color='orange',s=30)

ax.set_ylim([11250,12200])
ax.set_xlim([1683.3,1710])

#over plotting the flares that we identified


#axes
plt.rcParams['axes.linewidth']=1.1

plt.tick_params(axis='both',direction="in")
from matplotlib.ticker import (AutoMinorLocator,MultipleLocator)
ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.tick_params(which='minor', direction='in',width=1.2,length=4)
ax.yaxis.set_minor_locator(MultipleLocator(100))

plt.xlabel('Time - 2457000 [BTJD days]')
plt.ylabel('Flux [e- sec$^{-1}$]')
plt.tick_params(axis='both',direction="in",width=1.5,length=8)


plt.savefig('gj1243_tess_lc_rawflux.pdf',dpi=300, bbox_inches='tight', pad_inches=0.5)

# %% [markdown]
# ### TESS FFD

# %%
Lo=30.352907
ED = np.sort(fbeye['Equiv_Dur'][::-1])
time = (np.nanmedian(np.diff(gj1243_tess[11].time))) * (len(gj1243_tess[11].time))
nu = (np.arange(1, len(ED)+1)) / time

tess_x = np.log10(ED)[::-1] + (Lo)
#is is log(Lo)???
tess_y = np.log10(nu)

# %%
fig = plt.figure(figsize=(10,6))
font = {'size'   : 16}
plt.rc('font', **font)

plt.plot(tess_x,tess_y,'-o', color='C0', alpha=0.5)
plt.xlabel('log E (erg)')
plt.ylabel(r'log $\nu$ (day$^{-1}$)')
plt.title('GJ 1243 - TESS Sector 14')
# Out:
# Text(0.5, 1.0, 'GJ 1243 - TESS Sector 14')

# %% [markdown]
# ### Loading in Kepler data & flares from Davenport et al (2014)

# %%
# Kepler Flares
kep_Lo = 30.037849     #Jim calculated this value long time ago

kep_lc = pd.read_csv('https://raw.githubusercontent.com/jradavenport/GJ1243-Flares/1732d4130daf663532596749d566d8f78be8f7b2/data/gj1243_master_slc.dat', delim_whitespace=True, skiprows=1, 
                       names=('time', 'flux', 'error', 'detrended_flux'))
kep_dur = len(kep_lc) * 58.0 / 60./60./24.

kep_flare_table=pd.read_csv('https://raw.githubusercontent.com/jradavenport/GJ1243-Flares/master/data/gj1243_master_flares.tbl',
            skiprows=23,delim_whitespace=True,names=['index of flare start in "gj1243_master_slc.dat"',
                                                   'index of flare stop in "gj1243_master_slc.dat"','t_start','t_stop'
                                                   ,'t_peak','t_rise','t_decay','flux peak',
                                                   'ED','Duration of rise',
                                                   'Duration of decay','Complex flag',
                                                   '# of people that identified flare event exists',
                                                   '# of people that analyzed this month',
                                                   '# of flare template components fit to event'])

# %%
kep_x = np.log10(np.sort(kep_flare_table['ED'])[::-1]) + kep_Lo
kep_y = np.log10(np.arange(1, len(kep_x)+1) / kep_dur)
# Out:
# /Users/lupitatovar/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log10
#   """Entry point for launching an IPython kernel.

# %%
dL = 30.665290 - 30.037849
dL
# Out:
# 0.6274409999999975

# %% [markdown]
# ### Fitting the TESS Data

# %%
fig,ax = plt.subplots(figsize=(8,6))
font = {'size'   : 18}
plt.rc('font', **font)

plt.scatter(tess_x,tess_y, color='C0',s=10) #, label='TESS'
plt.scatter(kep_x,kep_y, color='k',s=1)
plt.xlabel('log (Flare Energy) [erg]')
plt.ylabel(r'log (Flare Frequency) [day$^{-1}$]')


# Add labels to the plot
style = dict(size=16)
ax.text(30.7, -0.5, "TESS", **style,color='C0')
ax.text(30, 0.95, "$\it{Kepler}$", **style)

#axes
plt.rcParams['axes.linewidth']=1.5

plt.tick_params(axis='both',direction="in")
from matplotlib.ticker import (AutoMinorLocator,MultipleLocator)
ax.xaxis.set_minor_locator(MultipleLocator(0.5))
ax.tick_params(which='minor', direction='in',width=1.2,length=4)
ax.yaxis.set_minor_locator(MultipleLocator(0.25))
plt.tick_params(axis='both',direction="in",width=1.5,length=8)


from scipy import polyfit

tess_polyfit,cov= np.polyfit(tess_x[1:30],tess_y[1:30],1,full=False, cov=True)

plt.plot(tess_x[1:30],np.polyval(tess_polyfit,tess_x[1:30]),color='red',linewidth=2.5)
print(tess_polyfit,np.sqrt(np.diag(cov))) #uncertainities on m and b
# Out:
# [-0.87041856 26.95874313] [0.02826251 0.88489708]

# %% [markdown]
# ### Fitting the Kepler Data

# %%
kepx_fit=np.log(np.sort(kep_flare_table['ED'])[::-1]) + kep_Lo
no_nan = kepx_fit[~np.isnan(kepx_fit)]
no_nan
# Out:
# /Users/lupitatovar/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.
# array([37.47454805, 37.22799347, 37.06310451, ..., 23.86740132,
#        22.92687534, 21.81407141])

# %%
kepx_fit=np.sort(kep_flare_table['ED'])[::-1] + kep_Lo
no_nan = kepx_fit[~np.isnan(kepx_fit)]
print(len(no_nan))
print(len(kep_y))
# Out:
# 6101
# 6107

# %%
kepy_fit=np.log10(np.arange(1, len(kep_x)+1) / kep_dur)

# %%
np.isfinite(kepx_fit)
# Out:
# array([False, False, False, ..., False, False, False])

# %%
no_nan_mask = np.isfinite(kepx_fit) 
plt.plot(kepx_fit[no_nan_mask], kepy_fit[no_nan_mask])

# %%
fig,ax = plt.subplots(figsize=(8,5))
font = {'size'   : 18}
plt.rc('font', **font)

plt.scatter(tess_x,tess_y, color='C0',s=10) #, label='TESS'
plt.scatter(kep_x,kep_y, color='k',s=1)
plt.xlabel('log (Flare Energy) [erg]')
plt.ylabel(r'log (Flare Frequency) [day$^{-1}$]')
#plt.title('GJ 1243')
#plt.legend() 

# Add labels to the plot
style = dict(size=16)
ax.text(30.7, -0.5, "TESS", **style,color='C0')
ax.text(30, 0.95, "$\it{Kepler}$", **style)

#axes
plt.rcParams['axes.linewidth']=1.5

#plt.tick_params(axis='both',direction="in")
#from matplotlib.ticker import (AutoMinorLocator,MultipleLocator)
#ax.xaxis.set_minor_locator(MultipleLocator(0.5))
#ax.tick_params(which='minor', direction='in')
#ax.yaxis.set_minor_locator(MultipleLocator(0.25))
#ax.xaxis.set_minor_locator(AutoMinorLocator())
#ax.yaxis.set_minor_locator(AutoMinorLocator())

from scipy import polyfit
kep_polyfit, cov = np.polyfit(kepx_fit[no_nan_mask][600:2500] ,kepy_fit[no_nan_mask][600:2500],1,full=False, cov=True)

plt.plot(kepx_fit[no_nan_mask][600:2500],np.polyval(kep_polyfit,kepx_fit[no_nan_mask][600:2500]),color='orange',linewidth=2.5)
kep_polyfit,np.sqrt(np.diag(cov)) #uncertainities on m and b
# Out:
# (array([-0.3301534, 10.8153449]), array([0.00046018, 0.01410547]))

# %%
len(no_nan_mask)
len(kepx_fit)
# Out:
# 6107

# %%
len(kepx_fit[no_nan_mask])
# Out:
# 5891

# %%
#Error Propagation

#Y errors
def Perror(n):
    err_down = n * (1. - 1. / (9. * n) -1./(3. * np.sqrt(n)))**3 - n
    err_up = n + np.sqrt(n + 0.75) + 1.0 - n 
    return err_down, err_up

#if the variable "ffd_y" is the cumulative # per day (NOT the log rate, yet), then you can quickly compute ffd_yerr as:

ffd_yerr = Perror(nu * time) / time

#where totdur is the total duration in days. 


#X Errors

dur = t_stops - t_starts
flux_err_tess= gj1243_tess[11].PDCSAP_FLUX.flux_err
S2N = ED / np.sqrt(ED + (flux_err_tess * dur * 86400.))

logED_err = np.abs((1./S2N) / np.log(10.) / ED)

#and finally:
ffd_xerr = np.abs(( (1./S2N[np.argsort(ED)])[::-1] ) / np.log(10.) / ffd_x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-243-0bc235bf5095> in <module>
#      18 dur = t_stops - t_starts
#      19 flux_err_tess= gj1243_tess[11].PDCSAP_FLUX.flux_err
# ---> 20 S2N = ED / np.sqrt(ED + (flux_err_tess * dur * 86400.))
#      21
#      22 logED_err = np.abs((1./S2N) / np.log(10.) / ED)
#
# ValueError: operands could not be broadcast together with shapes (18522,) (61,)

# %%
len(ED)
# Out:
# 61
